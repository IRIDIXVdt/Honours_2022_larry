# %%
import pandas as pd
import json

# %%
chapter = 15
df_process = pd.read_csv(f"../data/L{chapter}.csv", names=["spell","term","english"])
df_process
# Out:
#       spell   term                                    english
# 0         え      絵                 painting; picture; drawing
# 1     えいがかん    映画館                              movie theater
# 2    がいこくじん    外国人                                  foreigner
# 3        かぐ     家具                                  furniture
# 4      かんこう     観光                                sightseeing
# 5    けっこんしき    結婚式                                    wedding
# 6       じしん     地震                                 earthquake
# 7      しめきり   締め切り                                   deadline
# 8     ジャケット    NaN                                     jacket
# 9     しゅうかん     習慣                                     custom
# 10     ぜいきん     税金                                        tax
# 11  そつぎょうしき    卒業式                        graduation ceremony
# 12       そば    NaN                  Japanese buckwheat noodle
# 13       ちず     地図                                        map
# 14      でんち     電池                                    battery
# 15       にわ      庭                                     garden
# 16    はっぴょう     発表                               presentation
# 17     ばんぐみ     番組                          broadcast program
# 18      プール    NaN                              swimming pool
# 19      ペット    NaN                                        pet
# 20      よてい     予定                                   schedule
# 21     りょかん     旅館                                        inn
# 22   わりびきけん    割引券                            discount coupon
# 23      ひろい     広い                             spacious; wide
# 24       うる     売る                                    to sell
# 25      おろす    下ろす                        to withdraw (money)
# 26       かく    NaN                          to draw; to paint
# 27      さがす     探す                                to look for
# 28      さそう     誘う                                  to invite
# 29     つきあう   付き合う  (1) to date (someone) (2) to keep company
# 30       つく     着く                                  to arrive
# 31  ほけんにはいる  保険に入る                           to buy insurance
# 32    きをつける  気をつける                     to be cautious/careful
# 33     しらべる    調べる                    to look into (a matter)
# 34      すてる    捨てる                              to throw away
# 35      みえる    見える                              to be visible
# 36       する    NaN                     to decide on (an item)
# 37  そつぎょうする   卒業する                     to graduate (from ...)
# 38    よやくする   予約する                                 to reserve
# 39  いちにちじゅう    一日中                               all day long
# 40     さいきん     最近                                   recently

# %%
df_newTerm = df_process[["spell"]]
df_newTerm = df_newTerm.rename(columns={"spell": "term"})
# print(df_newTerm)
df_process = df_process.combine_first(df_newTerm)
df_process
# Out:
#                                       english    spell   term
# 0                  painting; picture; drawing        え      絵
# 1                               movie theater    えいがかん    映画館
# 2                                   foreigner   がいこくじん    外国人
# 3                                   furniture       かぐ     家具
# 4                                 sightseeing     かんこう     観光
# 5                                     wedding   けっこんしき    結婚式
# 6                                  earthquake      じしん     地震
# 7                                    deadline     しめきり   締め切り
# 8                                      jacket    ジャケット  ジャケット
# 9                                      custom    しゅうかん     習慣
# 10                                        tax     ぜいきん     税金
# 11                        graduation ceremony  そつぎょうしき    卒業式
# 12                  Japanese buckwheat noodle       そば     そば
# 13                                        map       ちず     地図
# 14                                    battery      でんち     電池
# 15                                     garden       にわ      庭
# 16                               presentation    はっぴょう     発表
# 17                          broadcast program     ばんぐみ     番組
# 18                              swimming pool      プール    プール
# 19                                        pet      ペット    ペット
# 20                                   schedule      よてい     予定
# 21                                        inn     りょかん     旅館
# 22                            discount coupon   わりびきけん    割引券
# 23                             spacious; wide      ひろい     広い
# 24                                    to sell       うる     売る
# 25                        to withdraw (money)      おろす    下ろす
# 26                          to draw; to paint       かく     かく
# 27                                to look for      さがす     探す
# 28                                  to invite      さそう     誘う
# 29  (1) to date (someone) (2) to keep company     つきあう   付き合う
# 30                                  to arrive       つく     着く
# 31                           to buy insurance  ほけんにはいる  保険に入る
# 32                     to be cautious/careful    きをつける  気をつける
# 33                    to look into (a matter)     しらべる    調べる
# 34                              to throw away      すてる    捨てる
# 35                              to be visible      みえる    見える
# 36                     to decide on (an item)       する     する
# 37                     to graduate (from ...)  そつぎょうする   卒業する
# 38                                 to reserve    よやくする   予約する
# 39                               all day long  いちにちじゅう    一日中
# 40                                   recently     さいきん     最近

# %%
df_process["def"] = df_process["spell"] + " - " + df_process["english"]
df_process["description"] = "ch" + str(chapter) + " #" 
for index, row in df_process.iterrows():
    # print("index is",index,"df is",row["description"])
    row["description"] = row["description"]+ str(index)
print(df_process)
# Out:
#                                       english    spell   term  \
# 0                  painting; picture; drawing        え      絵
# 1                               movie theater    えいがかん    映画館
# 2                                   foreigner   がいこくじん    外国人
# 3                                   furniture       かぐ     家具
# 4                                 sightseeing     かんこう     観光
# 5                                     wedding   けっこんしき    結婚式
# 6                                  earthquake      じしん     地震
# 7                                    deadline     しめきり   締め切り
# 8                                      jacket    ジャケット  ジャケット
# 9                                      custom    しゅうかん     習慣
# 10                                        tax     ぜいきん     税金
# 11                        graduation ceremony  そつぎょうしき    卒業式
# 12                  Japanese buckwheat noodle       そば     そば
# 13                                        map       ちず     地図
# 14                                    battery      でんち     電池
# 15                                     garden       にわ      庭
# 16                               presentation    はっぴょう     発表
# 17                          broadcast program     ばんぐみ     番組
# 18                              swimming pool      プール    プール
# 19                                        pet      ペット    ペット
# 20                                   schedule      よてい     予定
# 21                                        inn     りょかん     旅館
# 22                            discount coupon   わりびきけん    割引券
# 23                             spacious; wide      ひろい     広い
# 24                                    to sell       うる     売る
# 25                        to withdraw (money)      おろす    下ろす
# 26                          to draw; to paint       かく     かく
# 27                                to look for      さがす     探す
# 28                                  to invite      さそう     誘う
# 29  (1) to date (someone) (2) to keep company     つきあう   付き合う
# 30                                  to arrive       つく     着く
# 31                           to buy insurance  ほけんにはいる  保険に入る
# 32                     to be cautious/careful    きをつける  気をつける
# 33                    to look into (a matter)     しらべる    調べる
# 34                              to throw away      すてる    捨てる
# 35                              to be visible      みえる    見える
# 36                     to decide on (an item)       する     する
# 37                     to graduate (from ...)  そつぎょうする   卒業する
# 38                                 to reserve    よやくする   予約する
# 39                               all day long  いちにちじゅう    一日中
# 40                                   recently     さいきん     最近
#
#                                                  def description
# 0                     え - painting; picture; drawing     ch15 #0
# 1                              えいがかん - movie theater     ch15 #1
# 2                                 がいこくじん - foreigner     ch15 #2
# 3                                     かぐ - furniture     ch15 #3
# 4                                 かんこう - sightseeing     ch15 #4
# 5                                   けっこんしき - wedding     ch15 #5
# 6                                   じしん - earthquake     ch15 #6
# 7                                    しめきり - deadline     ch15 #7
# 8                                     ジャケット - jacket     ch15 #8
# 9                                     しゅうかん - custom     ch15 #9
# 10                                        ぜいきん - tax    ch15 #10
# 11                     そつぎょうしき - graduation ceremony    ch15 #11
# 12                    そば - Japanese buckwheat noodle    ch15 #12
# 13                                          ちず - map    ch15 #13
# 14                                     でんち - battery    ch15 #14
# 15                                       にわ - garden    ch15 #15
# 16                              はっぴょう - presentation    ch15 #16
# 17                          ばんぐみ - broadcast program    ch15 #17
# 18                               プール - swimming pool    ch15 #18
# 19                                         ペット - pet    ch15 #19
# 20                                    よてい - schedule    ch15 #20
# 21                                        りょかん - inn    ch15 #21
# 22                          わりびきけん - discount coupon    ch15 #22
# 23                              ひろい - spacious; wide    ch15 #23
# 24                                      うる - to sell    ch15 #24
# 25                         おろす - to withdraw (money)    ch15 #25
# 26                            かく - to draw; to paint    ch15 #26
# 27                                 さがす - to look for    ch15 #27
# 28                                   さそう - to invite    ch15 #28
# 29  つきあう - (1) to date (someone) (2) to keep company    ch15 #29
# 30                                    つく - to arrive    ch15 #30
# 31                        ほけんにはいる - to buy insurance    ch15 #31
# 32                    きをつける - to be cautious/careful    ch15 #32
# 33                    しらべる - to look into (a matter)    ch15 #33
# 34                               すてる - to throw away    ch15 #34
# 35                               みえる - to be visible    ch15 #35
# 36                       する - to decide on (an item)    ch15 #36
# 37                  そつぎょうする - to graduate (from ...)    ch15 #37
# 38                                よやくする - to reserve    ch15 #38
# 39                            いちにちじゅう - all day long    ch15 #39
# 40                                   さいきん - recently    ch15 #40

# %%
jsonItemArray = []
for index, row in df_process.iterrows():
    # print("index is",index,"df is",row["description"])
    des = row['description']
    qes = row['term']
    ans = row['def']
    template = '''{"type": "df",
        "background": "<p>What is the definition and pronunciation of the term?</p>",
        "course": "jpst200",
        "des": "''' + des + '''",
        "qaPair": [{ 
              "question": "''' + qes + '''",
              "answer": "''' + ans + '''"
              }],
        "wrongAnswer": []}'''
    # print(template)
    jsonDataItem = json.loads(template)
    # print(jsonDataItem)
    jsonItemArray.append(jsonDataItem)
jsonItemArray
# Out:
# [{'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #0',
#   'qaPair': [{'question': '絵', 'answer': 'え - painting; picture; drawing'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #1',
#   'qaPair': [{'question': '映画館', 'answer': 'えいがかん - movie theater'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #2',
#   'qaPair': [{'question': '外国人', 'answer': 'がいこくじん - foreigner'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #3',
#   'qaPair': [{'question': '家具', 'answer': 'かぐ - furniture'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #4',
#   'qaPair': [{'question': '観光', 'answer': 'かんこう - sightseeing'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #5',
#   'qaPair': [{'question': '結婚式', 'answer': 'けっこんしき - wedding'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #6',
#   'qaPair': [{'question': '地震', 'answer': 'じしん - earthquake'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #7',
#   'qaPair': [{'question': '締め切り', 'answer': 'しめきり - deadline'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #8',
#   'qaPair': [{'question': 'ジャケット', 'answer': 'ジャケット - jacket'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #9',
#   'qaPair': [{'question': '習慣', 'answer': 'しゅうかん - custom'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #10',
#   'qaPair': [{'question': '税金', 'answer': 'ぜいきん - tax'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #11',
#   'qaPair': [{'question': '卒業式', 'answer': 'そつぎょうしき - graduation ceremony'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #12',
#   'qaPair': [{'question': 'そば', 'answer': 'そば - Japanese buckwheat noodle'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #13',
#   'qaPair': [{'question': '地図', 'answer': 'ちず - map'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #14',
#   'qaPair': [{'question': '電池', 'answer': 'でんち - battery'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #15',
#   'qaPair': [{'question': '庭', 'answer': 'にわ - garden'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #16',
#   'qaPair': [{'question': '発表', 'answer': 'はっぴょう - presentation'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #17',
#   'qaPair': [{'question': '番組', 'answer': 'ばんぐみ - broadcast program'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #18',
#   'qaPair': [{'question': 'プール', 'answer': 'プール - swimming pool'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #19',
#   'qaPair': [{'question': 'ペット', 'answer': 'ペット - pet'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #20',
#   'qaPair': [{'question': '予定', 'answer': 'よてい - schedule'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #21',
#   'qaPair': [{'question': '旅館', 'answer': 'りょかん - inn'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #22',
#   'qaPair': [{'question': '割引券', 'answer': 'わりびきけん - discount coupon'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #23',
#   'qaPair': [{'question': '広い', 'answer': 'ひろい - spacious; wide'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #24',
#   'qaPair': [{'question': '売る', 'answer': 'うる - to sell'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #25',
#   'qaPair': [{'question': '下ろす', 'answer': 'おろす - to withdraw (money)'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #26',
#   'qaPair': [{'question': 'かく', 'answer': 'かく - to draw; to paint'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #27',
#   'qaPair': [{'question': '探す', 'answer': 'さがす - to look for'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #28',
#   'qaPair': [{'question': '誘う', 'answer': 'さそう - to invite'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #29',
#   'qaPair': [{'question': '付き合う',
#     'answer': 'つきあう - (1) to date (someone) (2) to keep company'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #30',
#   'qaPair': [{'question': '着く', 'answer': 'つく - to arrive'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #31',
#   'qaPair': [{'question': '保険に入る', 'answer': 'ほけんにはいる - to buy insurance'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #32',
#   'qaPair': [{'question': '気をつける',
#     'answer': 'きをつける - to be cautious/careful'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #33',
#   'qaPair': [{'question': '調べる', 'answer': 'しらべる - to look into (a matter)'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #34',
#   'qaPair': [{'question': '捨てる', 'answer': 'すてる - to throw away'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #35',
#   'qaPair': [{'question': '見える', 'answer': 'みえる - to be visible'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #36',
#   'qaPair': [{'question': 'する', 'answer': 'する - to decide on (an item)'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #37',
#   'qaPair': [{'question': '卒業する',
#     'answer': 'そつぎょうする - to graduate (from ...)'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #38',
#   'qaPair': [{'question': '予約する', 'answer': 'よやくする - to reserve'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #39',
#   'qaPair': [{'question': '一日中', 'answer': 'いちにちじゅう - all day long'}],
#   'wrongAnswer': []},
#  {'type': 'df',
#   'background': '<p>What is the definition and pronunciation of the term?</p>',
#   'course': 'jpst200',
#   'des': 'ch15 #40',
#   'qaPair': [{'question': '最近', 'answer': 'さいきん - recently'}],
#   'wrongAnswer': []}]

# %%
with open("../data/verbChpt"+str(chapter)+".json", "w") as outfile:
    json.dump(jsonItemArray, outfile)
