# %%
import pandas as pd
import json

# %%
chapter = 15
df_process = pd.read_csv(f"../data/L{chapter}.csv", names=["spell","term","english"])
df_process
# Out:
#        spell   term                                    english
# 0      ぬいぐるみ    NaN          stuffed animal (e.g., teddy bear)
# 1         あに      兄                         (my) older brother
# 2      おおやさん   大家さん                                   landlord
# 3       おかえし    お返し           return (as a token of gratitude)
# 4       おくさん    奥さん                            (your/his) wife
# 5       おじさん    NaN                     uncle; middle-aged man
# 6       おばさん    NaN                    aunt; middle-aged woman
# 7        クラブ    NaN                      club; student society
# 8      クリスマス    NaN                                  Christmas
# 9      ごしゅじん    NaN                         (your/her) husband
# 10       コップ    NaN                             tumbler; glass
# 11        さら      皿                                plate; dish
# 12       じかん     時間                                       time
# 13    チョコレート    NaN                                  chocolate
# 14    でんしメール  電子メール                                     e-mail
# 15      ネクタイ    NaN                                    necktie
# 16        はは      母                                (my) mother
# 17  バレンタインデー    NaN                        St. Valentine's Day
# 18    ビデオカメラ    NaN                                  camcorder
# 19       ふうふ     夫婦           married couple; husband and wife
# 20    ホワイトデー    NaN  "White Day" (yet another gift-giving day)
# 21      マフラー    NaN                               winter scarf
# 22       まんが     漫画                                 comic book
# 23     マンション    NaN          multistory apartment; condominium
# 24       みかん    NaN                                   mandarin
# 25       ゆびわ     指輪                                       ring
# 26     りょうしん     両親                                    parents
# 27     りれきしょ    履歴書                                     resume
# 28       ほしい    欲しい                                    to want
# 29        けち    NaN                              stingy; cheap
# 30       おくる     送る                                    to send
# 31       にあう    似合う                 to look good (on somebody)
# 32     あきらめる    NaN                                 to give up
# 33       あげる    NaN                        to give (to others)
# 34       くれる    NaN                               to give (me)
# 35       できる    NaN         to come into existence; to be made
# 36    そうだんする   相談する                                 to consult
# 37   プロポーズする    NaN                        to propose marriage
# 38       おなじ     同じ                                       same
# 39      きょねん     去年                                  last year
# 40     わたしたち    私たち                                         we
# 41      ちょうど    NaN                                    exactly
# 42        よく    NaN                                       well
# 43         こ      個        [generic counter for smaller items]
# 44        さつ      冊                [counter for bound volumes]
# 45        だい      台                    [counter for equipment]
# 46        ひき      匹              [counter for smaller animals]
# 47        ぽん      本                 [counter for long objects]

# %%
df_newTerm = df_process[["spell"]]
df_newTerm = df_newTerm.rename(columns={"spell": "term"})
# print(df_newTerm)
df_process = df_process.combine_first(df_newTerm)
df_process
# Out:
#                                       english     spell      term
# 0           stuffed animal (e.g., teddy bear)     ぬいぐるみ     ぬいぐるみ
# 1                          (my) older brother        あに         兄
# 2                                    landlord     おおやさん      大家さん
# 3            return (as a token of gratitude)      おかえし       お返し
# 4                             (your/his) wife      おくさん       奥さん
# 5                      uncle; middle-aged man      おじさん      おじさん
# 6                     aunt; middle-aged woman      おばさん      おばさん
# 7                       club; student society       クラブ       クラブ
# 8                                   Christmas     クリスマス     クリスマス
# 9                          (your/her) husband     ごしゅじん     ごしゅじん
# 10                             tumbler; glass       コップ       コップ
# 11                                plate; dish        さら         皿
# 12                                       time       じかん        時間
# 13                                  chocolate    チョコレート    チョコレート
# 14                                     e-mail    でんしメール     電子メール
# 15                                    necktie      ネクタイ      ネクタイ
# 16                                (my) mother        はは         母
# 17                        St. Valentine's Day  バレンタインデー  バレンタインデー
# 18                                  camcorder    ビデオカメラ    ビデオカメラ
# 19           married couple; husband and wife       ふうふ        夫婦
# 20  "White Day" (yet another gift-giving day)    ホワイトデー    ホワイトデー
# 21                               winter scarf      マフラー      マフラー
# 22                                 comic book       まんが        漫画
# 23          multistory apartment; condominium     マンション     マンション
# 24                                   mandarin       みかん       みかん
# 25                                       ring       ゆびわ        指輪
# 26                                    parents     りょうしん        両親
# 27                                     resume     りれきしょ       履歴書
# 28                                    to want       ほしい       欲しい
# 29                              stingy; cheap        けち        けち
# 30                                    to send       おくる        送る
# 31                 to look good (on somebody)       にあう       似合う
# 32                                 to give up     あきらめる     あきらめる
# 33                        to give (to others)       あげる       あげる
# 34                               to give (me)       くれる       くれる
# 35         to come into existence; to be made       できる       できる
# 36                                 to consult    そうだんする      相談する
# 37                        to propose marriage   プロポーズする   プロポーズする
# 38                                       same       おなじ        同じ
# 39                                  last year      きょねん        去年
# 40                                         we     わたしたち       私たち
# 41                                    exactly      ちょうど      ちょうど
# 42                                       well        よく        よく
# 43        [generic counter for smaller items]         こ         個
# 44                [counter for bound volumes]        さつ         冊
# 45                    [counter for equipment]        だい         台
# 46              [counter for smaller animals]        ひき         匹
# 47                 [counter for long objects]        ぽん         本

# %%
df_process["def"] = df_process["spell"] + " - " + df_process["english"]
df_process["description"] = "ch" + str(chapter) + " #" 
for index, row in df_process.iterrows():
    # print("index is",index,"df is",row["description"])
    row["description"] = row["description"]+ str(index)
print(df_process)
# Out:
#                                       english     spell      term  \
# 0           stuffed animal (e.g., teddy bear)     ぬいぐるみ     ぬいぐるみ
# 1                          (my) older brother        あに         兄
# 2                                    landlord     おおやさん      大家さん
# 3            return (as a token of gratitude)      おかえし       お返し
# 4                             (your/his) wife      おくさん       奥さん
# 5                      uncle; middle-aged man      おじさん      おじさん
# 6                     aunt; middle-aged woman      おばさん      おばさん
# 7                       club; student society       クラブ       クラブ
# 8                                   Christmas     クリスマス     クリスマス
# 9                          (your/her) husband     ごしゅじん     ごしゅじん
# 10                             tumbler; glass       コップ       コップ
# 11                                plate; dish        さら         皿
# 12                                       time       じかん        時間
# 13                                  chocolate    チョコレート    チョコレート
# 14                                     e-mail    でんしメール     電子メール
# 15                                    necktie      ネクタイ      ネクタイ
# 16                                (my) mother        はは         母
# 17                        St. Valentine's Day  バレンタインデー  バレンタインデー
# 18                                  camcorder    ビデオカメラ    ビデオカメラ
# 19           married couple; husband and wife       ふうふ        夫婦
# 20  "White Day" (yet another gift-giving day)    ホワイトデー    ホワイトデー
# 21                               winter scarf      マフラー      マフラー
# 22                                 comic book       まんが        漫画
# 23          multistory apartment; condominium     マンション     マンション
# 24                                   mandarin       みかん       みかん
# 25                                       ring       ゆびわ        指輪
# 26                                    parents     りょうしん        両親
# 27                                     resume     りれきしょ       履歴書
# 28                                    to want       ほしい       欲しい
# 29                              stingy; cheap        けち        けち
# 30                                    to send       おくる        送る
# 31                 to look good (on somebody)       にあう       似合う
# 32                                 to give up     あきらめる     あきらめる
# 33                        to give (to others)       あげる       あげる
# 34                               to give (me)       くれる       くれる
# 35         to come into existence; to be made       できる       できる
# 36                                 to consult    そうだんする      相談する
# 37                        to propose marriage   プロポーズする   プロポーズする
# 38                                       same       おなじ        同じ
# 39                                  last year      きょねん        去年
# 40                                         we     わたしたち       私たち
# 41                                    exactly      ちょうど      ちょうど
# 42                                       well        よく        よく
# 43        [generic counter for smaller items]         こ         個
# 44                [counter for bound volumes]        さつ         冊
# 45                    [counter for equipment]        だい         台
# 46              [counter for smaller animals]        ひき         匹
# 47                 [counter for long objects]        ぽん         本
#
#                                                   def description
# 0           ぬいぐるみ - stuffed animal (e.g., teddy bear)     ch14 #0
# 1                             あに - (my) older brother     ch14 #1
# 2                                    おおやさん - landlord     ch14 #2
# 3             おかえし - return (as a token of gratitude)     ch14 #3
# 4                              おくさん - (your/his) wife     ch14 #4
# 5                       おじさん - uncle; middle-aged man     ch14 #5
# 6                      おばさん - aunt; middle-aged woman     ch14 #6
# 7                         クラブ - club; student society     ch14 #7
# 8                                   クリスマス - Christmas     ch14 #8
# 9                          ごしゅじん - (your/her) husband     ch14 #9
# 10                               コップ - tumbler; glass    ch14 #10
# 11                                   さら - plate; dish    ch14 #11
# 12                                         じかん - time    ch14 #12
# 13                                 チョコレート - chocolate    ch14 #13
# 14                                    でんしメール - e-mail    ch14 #14
# 15                                     ネクタイ - necktie    ch14 #15
# 16                                   はは - (my) mother    ch14 #16
# 17                     バレンタインデー - St. Valentine's Day    ch14 #17
# 18                                 ビデオカメラ - camcorder    ch14 #18
# 19             ふうふ - married couple; husband and wife    ch14 #19
# 20  ホワイトデー - "White Day" (yet another gift-giving ...    ch14 #20
# 21                                マフラー - winter scarf    ch14 #21
# 22                                   まんが - comic book    ch14 #22
# 23          マンション - multistory apartment; condominium    ch14 #23
# 24                                     みかん - mandarin    ch14 #24
# 25                                         ゆびわ - ring    ch14 #25
# 26                                    りょうしん - parents    ch14 #26
# 27                                     りれきしょ - resume    ch14 #27
# 28                                      ほしい - to want    ch14 #28
# 29                                 けち - stingy; cheap    ch14 #29
# 30                                      おくる - to send    ch14 #30
# 31                   にあう - to look good (on somebody)    ch14 #31
# 32                                 あきらめる - to give up    ch14 #32
# 33                          あげる - to give (to others)    ch14 #33
# 34                                 くれる - to give (me)    ch14 #34
# 35           できる - to come into existence; to be made    ch14 #35
# 36                                そうだんする - to consult    ch14 #36
# 37                      プロポーズする - to propose marriage    ch14 #37
# 38                                         おなじ - same    ch14 #38
# 39                                   きょねん - last year    ch14 #39
# 40                                         わたしたち - we    ch14 #40
# 41                                     ちょうど - exactly    ch14 #41
# 42                                          よく - well    ch14 #42
# 43            こ - [generic counter for smaller items]    ch14 #43
# 44                   さつ - [counter for bound volumes]    ch14 #44
# 45                       だい - [counter for equipment]    ch14 #45
# 46                 ひき - [counter for smaller animals]    ch14 #46
# 47                    ぽん - [counter for long objects]    ch14 #47

# %%
jsonItemArray = []
for index, row in df_process.iterrows():
    # print("index is",index,"df is",row["description"])
    des = row['description']
    qes = row['term']
    ans = row['def']
    template = '''{"type": "df",
        "background": "<p>What is the definition and pronunciation of the term?</p>",
        "course": "jpst200",
        "des": "''' + des + '''",
        "qaPair": [{ 
              "question": "''' + qes + '''",
              "answer": "''' + ans + '''"
              }],
        "wrongAnswer": []}'''
    # print(template)
    jsonDataItem = json.loads(template)
    # print(jsonDataItem)
    jsonItemArray.append(jsonDataItem)
jsonItemArray
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22568/2092217572.py in <module>
#      15         "wrongAnswer": []}'''
#      16     # print(template)
# ---> 17     jsonDataItem = json.loads(template)
#      18     # print(jsonDataItem)
#      19     jsonItemArray.append(jsonDataItem)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 7 column 36 (char 250)

# %%
with open("../data/verbChpt"+str(chapter)+".json", "w") as outfile:
    json.dump(jsonItemArray, outfile)
